# %% [markdown]
# # **TUGAS 5**
# tugas pendata :
# - knime (naive bayyes linier&predictor) & menggunakan scrip dr library sklearn, pada klasiflayer,
# - data bebas u/klasifikasi naive bayyes
# - beserta penjelasan
# - dan ditampilkan web statis

# %% [markdown]
# Dataset : [Dataset Penyakit Jantung uci](https://www.kaggle.com/datasets/redwankarimsony/heart-disease-data)
